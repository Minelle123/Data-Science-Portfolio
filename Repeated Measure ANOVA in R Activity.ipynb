# %%
install.packages('fastR2')
install.packages('mosaic')
# Out:
# Installing package into 'C:/Users/minel/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'fastR2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\minel\AppData\Local\Temp\RtmpsZX4oL\downloaded_packages
# Installing package into 'C:/Users/minel/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'ggformula', 'mosaicData', 'mosaicCore'
# package 'ggformula' successfully unpacked and MD5 sums checked
# package 'mosaicData' successfully unpacked and MD5 sums checked
# package 'mosaicCore' successfully unpacked and MD5 sums checked
# package 'mosaic' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\minel\AppData\Local\Temp\RtmpsZX4oL\downloaded_packages

# %%
install.packages('tweenr')
# Out:
# Installing package into 'C:/Users/minel/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'tweenr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\minel\AppData\Local\Temp\RtmpsZX4oL\downloaded_packages

# %%
library("rcompanion")
library("fastR2")
library("car")
# Out:
# Loading required package: mosaic
#
# Registered S3 method overwritten by 'mosaic':
#   method                           from
#   fortify.SpatialPolygonsDataFrame ggplot2
#
#
# The 'mosaic' package masks several functions from core packages in order to add
# additional features.  The original behavior of these functions should not be affected by this.
#
#
# Attaching package: 'mosaic'
#
#
# The following objects are masked from 'package:dplyr':
#
#     count, do, tally
#
#
# The following object is masked from 'package:Matrix':
#
#     mean
#
#
# The following object is masked from 'package:ggplot2':
#
#     stat
#
#
# The following objects are masked from 'package:stats':
#
#     binom.test, cor, cor.test, cov, fivenum, IQR, median, prop.test,
#     quantile, sd, t.test, var
#
#
# The following objects are masked from 'package:base':
#
#     max, mean, min, prod, range, sample, sum
#
#
# Loading required package: carData
#
#
# Attaching package: 'car'
#
#
# The following objects are masked from 'package:mosaic':
#
#     deltaMethod, logit
#
#
# The following object is masked from 'package:dplyr':
#
#     recode

# %%
breakfast1 <- read.csv("C:/Users/minel/OneDrive/Documents/Entity Coursework/DSO105C (Oct 3 - Oct 23)/Lesson 5/breakfast.csv")

# %%
breakfast1 <- breakfast1[1:33,1:7]

# %%
keeps <- c("Participant.Code", "Treatment.Group", "Age..y.", "Sex", "Height..m.", "Baseline.Resting.Metabolic.Rate..kcal.d.", "Follow.Up.Resting.Metabolic.Rate..kcal.d.")

# %%
breakfast2 <- breakfast1[keeps]
# Out:
# Error in `[.data.frame`(breakfast1, keeps): undefined columns selected
# Traceback:
#
# 1. breakfast1[keeps]
# 2. `[.data.frame`(breakfast1, keeps)
# 3. stop("undefined columns selected")

# %%
breakfast3 <- breakfast2[,1:5]
breakfast3$repdat <- breakfast2$Baseline.Body.Mass..kg.
breakfast3$contrasts <- "T1"
# Out:
# Error in eval(expr, envir, enclos): object 'breakfast2' not found
# Traceback:

# %%
breakfast4 <- breakfast2[,1:5]
breakfast4$repdat <- breakfast2$Follow.Up.Body.Mass..kg.
breakfast4$contrasts <- "T2"
# Out:
# Error in eval(expr, envir, enclos): object 'breakfast2' not found
# Traceback:

# %%
breakfast5 <- rbind(breakfast3, breakfast4)
# Out:
# Error in rbind(breakfast3, breakfast4): object 'breakfast3' not found
# Traceback:
#
# 1. rbind(breakfast3, breakfast4)

# %%
plotNormalHistogram(breakfast1$Baseline.Body.Mass..kg.)
plotNormalHistogram(breakfast1$Follow.Up.Body.Mass..kg.)
# Out:
# Plot with title ""
# Plot with title ""

# %%
leveneTest(repdat ~ Treatment.Group*contrasts, data=breakfast5)
# Out:
# Error in is.data.frame(data): object 'breakfast5' not found
# Traceback:
#
# 1. leveneTest(repdat ~ Treatment.Group * contrasts, data = breakfast5)
# 2. leveneTest.formula(repdat ~ Treatment.Group * contrasts, data = breakfast5)
# 3. model.frame(form, data)
# 4. model.frame.default(form, data)
# 5. is.data.frame(data)

# %%
RManova2 <- aov(repdat~contrasts+Error(Participant.Code), breakfast5)
summary(RManova2)
# Out:
# Error in terms.formula(formula, "Error", data = data): object 'breakfast5' not found
# Traceback:
#
# 1. aov(repdat ~ contrasts + Error(Participant.Code), breakfast5)
# 2. terms(formula, "Error", data = data)
# 3. terms.formula(formula, "Error", data = data)
