# %%
library('dplyr')
library('rcompanion')
library('car')
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: carData
#
#
# Attaching package: 'car'
#
#
# The following object is masked from 'package:dplyr':
#
#     recode

# %%
Avocado <- read.csv("C:/Users/minel/OneDrive/Documents/Entity Coursework/DSO105C (Oct 3 - Oct 23)/Lesson 4/avocados.csv")

# %%
plotNormalHistogram(Avocado$AveragePrice)
# Out:
# Plot with title ""

# %%
Avocado$SQRT <- sqrt(Avocado$AveragePrice)
plotNormalHistogram(Avocado$AveragePriceSQRT)
# Out:
# Warning message in min(x):
# "no non-missing arguments to min; returning Inf"
# Warning message in max(x):
# "no non-missing arguments to max; returning -Inf"
# Error in seq.default(min(x), max(x), length = length): 'from' must be a finite number
# Traceback:
#
# 1. plotNormalHistogram(Avocado$AveragePriceSQRT)
# 2. seq(min(x), max(x), length = length)
# 3. seq.default(min(x), max(x), length = length)
# 4. stop("'from' must be a finite number")

# %%
Avocado$AveragePriceLOG <- log(Avocado$AveragePrice)
plotNormalHistogram(Avocado$AveragePriceLOG)
# Out:
# Plot with title ""

# %%
bartlett.test(AveragePriceSQRT ~ region, Avocado)
# Out:
# Error in eval(predvars, data, env): object 'AveragePriceSQRT' not found
# Traceback:
#
# 1. bartlett.test(AveragePriceSQRT ~ region, Avocado)
# 2. bartlett.test.formula(AveragePriceSQRT ~ region, Avocado)
# 3. eval(m, parent.frame())
# 4. eval(m, parent.frame())
# 5. stats::model.frame(formula = AveragePriceSQRT ~ region, data = Avocado)
# 6. model.frame.default(formula = AveragePriceSQRT ~ region, data = Avocado)
# 7. eval(predvars, data, env)
# 8. eval(predvars, data, env)

# %%
pairwise.t.test(Avocado$AveragePriceSQRT, Avocado$type, p.adjust="Total Volume", XLarge.Bags.sd = FALSE)
# Out:
# Error in match.arg(p.adjust.method): 'arg' should be one of "holm", "hochberg", "hommel", "bonferroni", "BH", "BY", "fdr", "none"
# Traceback:
#
# 1. pairwise.t.test(Avocado$AveragePriceSQRT, Avocado$type, p.adjust = "Total Volume",
#  .     XLarge.Bags.sd = FALSE)
# 2. match.arg(p.adjust.method)
# 3. stop(gettextf("'arg' should be one of %s", paste(dQuote(choices),
#  .     collapse = ", ")), domain = NA)

# %%
AvocadoMeans <- Avocado %>% group_by(Total.Volume) %>% summarize(Mean = mean(AveragePrice)
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:0: unexpected end of input
# 1: AvocadoMeans <- Avocado %>% group_by(Total.Volume) %>% summarize(Mean = mean(AveragePrice)
#    ^
# Traceback:
